# %% [markdown]
# # matplotlib 사용

# %%
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../libraries/')
import hangul_lib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-4f0cc85a3e42> in <module>
#       1 import sys
#       2 sys.path.append('../libraries/')
# ----> 3 import hangul_lib
#
# ModuleNotFoundError: No module named 'hangul_lib'

# %%
import matplotlib.pyplot as plt

data = [20, 30, 40]
x = [1, 2, 4]
plt.plot(x, data)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

xdata = ['안지영','홍지수','황예린']
ydata1 = [90, 85, 88]
ydata2 = [83, 88, 91]
plt.plot(xdata, ydata1, label = '국어')
plt.plot(xdata, ydata2, label = '영어')
plt.legend(loc='upper center')

plt.title('세명 학생의 국어, 영어 성적')

plt.show()

# %%
import matplotlib.pyplot as plt

data = [50, 30, 40]
x = ['가반', '나반', '다반']
plt.bar(x, data)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['월','화','수','목','금','토','일']
y = [6.5, 5.7, 5.5, 6.7, 7.5, 8.3, 5.6]
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

pets = ['개','고양이','기타','안기름']
portion = [1.8, 3.4, 3.1, 75.5]
